# %% [markdown]
# Importação dos dados que estão presente em um repositório no Github no formato de arquivos .csv

# %%
import pandas as pd
import numpy as np

# %%
cyl_00 = pd.read_csv('https://github.com/ascdavia/DeepLearning_SignalProcessing-sEMG/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/df1_mov_cyl.csv?raw=true', compression=None)
hook_00 = pd.read_csv('https://github.com/ascdavia/DeepLearning_SignalProcessing-sEMG/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/df1_mov_hook.csv?raw=true', compression=None)
lat_00 = pd.read_csv('https://github.com/ascdavia/DeepLearning_SignalProcessing-sEMG/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/df1_mov_lat.csv?raw=true', compression=None)
palm_00 = pd.read_csv('https://github.com/ascdavia/DeepLearning_SignalProcessing-sEMG/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/df1_mov_palm.csv?raw=true', compression=None)
spher_00 = pd.read_csv('https://github.com/ascdavia/DeepLearning_SignalProcessing-sEMG/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/df1_mov_spher.csv?raw=true', compression=None)
tip_00 = pd.read_csv('https://github.com/ascdavia/DeepLearning_SignalProcessing-sEMG/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/df1_mov_tip.csv?raw=true', compression=None)

# %%
cyl_01 = cyl_00.drop(cyl_00.columns[0], axis=1)
hook_01 = hook_00.drop(hook_00.columns[0], axis=1)
lat_01 = lat_00.drop(lat_00.columns[0], axis=1)
palm_01 = palm_00.drop(palm_00.columns[0], axis=1)
spher_01 = spher_00.drop(spher_00.columns[0], axis=1)
tip_01 = tip_00.drop(tip_00.columns[0], axis=1)

# %%
cyl = np.array_split(cyl_01, 30, axis=1)
hook = np.array_split(hook_01, 30, axis=1)
lat = np.array_split(lat_01, 30, axis=1)
palm = np.array_split(palm_01, 30, axis=1)
spher = np.array_split(spher_01, 30, axis=1)
tip = np.array_split(tip_01, 30, axis=1)

# %%
def concatDf (df):
  aux_df = pd.DataFrame(columns = df[0].columns)

  for i in range (30):
  
    a = df[i].T.reset_index(drop=True).T
    aux_df = pd.concat([aux_df,a])

  aux_df_2 = aux_df.reset_index(drop=True)

  return aux_df_2

# %%
cyl_DA = concatDf (cyl)
hook_DA = concatDf(hook)
lat_DA = concatDf(lat)
palm_DA = concatDf(palm)
spher_DA = concatDf(spher)
tip_DA = concatDf(tip)

# %% [markdown]
# Definição da matriz de entrada *x*

# %%
x = pd.concat([cyl_DA,hook_DA,lat_DA,palm_DA,spher_DA,tip_DA], ignore_index=True)
x = x.dropna(axis=1)

# %%
x = x.values.reshape(x.shape[0], x.shape[1], 1) #comando necessário para colocar a matriz de entrada x em um formato compatível com os neurônios de um CNN. Neste caso, foi necessário fazer uma camada de profundidade igual a 1.
print(x.shape)
# Out:
# (27000, 100, 1)

# %% [markdown]
# Definição da matriz de saída *y*

# %%
base = np.ones((4500,1), dtype=np.int64)
mov_cyl = base*0
mov_hook = base*1
mov_lat = base*2
mov_palm = base*3
mov_spher = base*4
mov_tip = base*5

# %%
mov = np.vstack([mov_cyl,mov_hook,mov_lat,mov_palm,mov_spher,mov_tip])
y = pd.DataFrame(mov)

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %% [markdown]
# CNN 1D - Modelo com 2 layers de convolução

# %%
import keras
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import GlobalAveragePooling1D
from keras.layers import Flatten

# %%
num_classes = 6

model = keras.models.Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Conv1D(32, kernel_size=3, activation='relu'))
model.add(Conv1D(32, kernel_size=1, activation='relu'))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 98, 32)            128
#
#  conv1d_1 (Conv1D)           (None, 96, 32)            3104
#
#  conv1d_2 (Conv1D)           (None, 96, 32)            1056
#
#  flatten (Flatten)           (None, 3072)              0
#
#  dropout (Dropout)           (None, 3072)              0
#
#  dense (Dense)               (None, 6)                 18438
#
# =================================================================
# Total params: 22,726
# Trainable params: 22,726
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
treino = model.fit(x_train, y_train, batch_size=16, epochs=300)
# Out:
# Epoch 1/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 1.4673 - accuracy: 0.3428
# Epoch 2/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.3714 - accuracy: 0.4041
# Epoch 3/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.3270 - accuracy: 0.4255
# Epoch 4/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.2921 - accuracy: 0.4448
# Epoch 5/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.2627 - accuracy: 0.4551
# Epoch 6/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.2406 - accuracy: 0.4664
# Epoch 7/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.2230 - accuracy: 0.4760
# Epoch 8/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.2095 - accuracy: 0.4876
# Epoch 9/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.1933 - accuracy: 0.4916
# Epoch 10/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.1867 - accuracy: 0.4930
# Epoch 11/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.1789 - accuracy: 0.4989
# Epoch 12/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.1671 - accuracy: 0.5047
# Epoch 13/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.1578 - accuracy: 0.5091
# Epoch 14/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.1518 - accuracy: 0.5168
# Epoch 15/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.1463 - accuracy: 0.5175
# Epoch 16/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.1316 - accuracy: 0.5256
# Epoch 17/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.1288 - accuracy: 0.5299
# Epoch 18/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.1248 - accuracy: 0.5296
# Epoch 19/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.1159 - accuracy: 0.5363
# Epoch 20/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.1133 - accuracy: 0.5404
# Epoch 21/300
# 1131/1131 [==============================] - 8s 8ms/step - loss: 1.1075 - accuracy: 0.5407
# Epoch 22/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.1099 - accuracy: 0.5390
# Epoch 23/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0975 - accuracy: 0.5443
# Epoch 24/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0942 - accuracy: 0.5443
# Epoch 25/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0948 - accuracy: 0.5467
# Epoch 26/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0965 - accuracy: 0.5471
# Epoch 27/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0836 - accuracy: 0.5517
# Epoch 28/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0823 - accuracy: 0.5574
# Epoch 29/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0792 - accuracy: 0.5546
# Epoch 30/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0823 - accuracy: 0.5549
# Epoch 31/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0751 - accuracy: 0.5565
# Epoch 32/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0726 - accuracy: 0.5613
# Epoch 33/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0676 - accuracy: 0.5619
# Epoch 34/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0755 - accuracy: 0.5589
# Epoch 35/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0680 - accuracy: 0.5591
# Epoch 36/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0590 - accuracy: 0.5650
# Epoch 37/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0640 - accuracy: 0.5599
# Epoch 38/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0668 - accuracy: 0.5567
# Epoch 39/300
# 1131/1131 [==============================] - 8s 8ms/step - loss: 1.0596 - accuracy: 0.5666
# Epoch 40/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0573 - accuracy: 0.5645
# Epoch 41/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0534 - accuracy: 0.5646
# Epoch 42/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0566 - accuracy: 0.5648
# Epoch 43/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0464 - accuracy: 0.5710
# Epoch 44/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0482 - accuracy: 0.5705
# Epoch 45/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0497 - accuracy: 0.5676
# Epoch 46/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0495 - accuracy: 0.5676
# Epoch 47/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0410 - accuracy: 0.5752
# Epoch 48/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0321 - accuracy: 0.5836
# Epoch 49/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0434 - accuracy: 0.5742
# Epoch 50/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0334 - accuracy: 0.5762
# Epoch 51/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0314 - accuracy: 0.5745
# Epoch 52/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0304 - accuracy: 0.5798
# Epoch 53/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0290 - accuracy: 0.5764
# Epoch 54/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0323 - accuracy: 0.5778
# Epoch 55/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0340 - accuracy: 0.5804
# Epoch 56/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0187 - accuracy: 0.5855
# Epoch 57/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0302 - accuracy: 0.5777
# Epoch 58/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0213 - accuracy: 0.5812
# Epoch 59/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0242 - accuracy: 0.5843
# Epoch 60/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0245 - accuracy: 0.5777
# Epoch 61/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0225 - accuracy: 0.5817
# Epoch 62/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 1.0197 - accuracy: 0.5837
# Epoch 63/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 1.0225 - accuracy: 0.5805
# Epoch 64/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 1.0155 - accuracy: 0.5867
# Epoch 65/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 1.0242 - accuracy: 0.5793
# Epoch 66/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0138 - accuracy: 0.5880
# Epoch 67/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0236 - accuracy: 0.5807
# Epoch 68/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0110 - accuracy: 0.5843
# Epoch 69/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0166 - accuracy: 0.5855
# Epoch 70/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0158 - accuracy: 0.5878
# Epoch 71/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0116 - accuracy: 0.5867
# Epoch 72/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0101 - accuracy: 0.5866
# Epoch 73/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0123 - accuracy: 0.5866
# Epoch 74/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 1.0064 - accuracy: 0.5891
# Epoch 75/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0155 - accuracy: 0.5842
# Epoch 76/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0097 - accuracy: 0.5918
# Epoch 77/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0056 - accuracy: 0.5888
# Epoch 78/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0077 - accuracy: 0.5877
# Epoch 79/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0108 - accuracy: 0.5888
# Epoch 80/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0002 - accuracy: 0.5919
# Epoch 81/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0038 - accuracy: 0.5930
# Epoch 82/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0007 - accuracy: 0.5920
# Epoch 83/300
# 1131/1131 [==============================] - 8s 8ms/step - loss: 1.0040 - accuracy: 0.5931
# Epoch 84/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0035 - accuracy: 0.5933
# Epoch 85/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9969 - accuracy: 0.5943
# Epoch 86/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9980 - accuracy: 0.5984
# Epoch 87/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9989 - accuracy: 0.5945
# Epoch 88/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0004 - accuracy: 0.5963
# Epoch 89/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 1.0021 - accuracy: 0.5936
# Epoch 90/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9944 - accuracy: 0.5930
# Epoch 91/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9923 - accuracy: 0.5976
# Epoch 92/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9977 - accuracy: 0.5949
# Epoch 93/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9940 - accuracy: 0.5965
# Epoch 94/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9919 - accuracy: 0.5946
# Epoch 95/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9897 - accuracy: 0.5982
# Epoch 96/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9893 - accuracy: 0.5991
# Epoch 97/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9953 - accuracy: 0.5952
# Epoch 98/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9884 - accuracy: 0.5965
# Epoch 99/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 1.0043 - accuracy: 0.5933
# Epoch 100/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9852 - accuracy: 0.6020
# Epoch 101/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9835 - accuracy: 0.5994
# Epoch 102/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9858 - accuracy: 0.5971
# Epoch 103/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9930 - accuracy: 0.5956
# Epoch 104/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9854 - accuracy: 0.6048
# Epoch 105/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9852 - accuracy: 0.5999
# Epoch 106/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9865 - accuracy: 0.5975
# Epoch 107/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9879 - accuracy: 0.5964
# Epoch 108/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9865 - accuracy: 0.5984
# Epoch 109/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9762 - accuracy: 0.6045
# Epoch 110/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9889 - accuracy: 0.5988
# Epoch 111/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9831 - accuracy: 0.6013
# Epoch 112/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9825 - accuracy: 0.6027
# Epoch 113/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9881 - accuracy: 0.5949
# Epoch 114/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9786 - accuracy: 0.6057
# Epoch 115/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9836 - accuracy: 0.5981
# Epoch 116/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9775 - accuracy: 0.6024
# Epoch 117/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9774 - accuracy: 0.6030
# Epoch 118/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9820 - accuracy: 0.6023
# Epoch 119/300
# 1131/1131 [==============================] - 8s 8ms/step - loss: 0.9790 - accuracy: 0.6050
# Epoch 120/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9692 - accuracy: 0.6080
# Epoch 121/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9811 - accuracy: 0.6026
# Epoch 122/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9776 - accuracy: 0.6039
# Epoch 123/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9757 - accuracy: 0.6069
# Epoch 124/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9795 - accuracy: 0.5992
# Epoch 125/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9678 - accuracy: 0.6098
# Epoch 126/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9775 - accuracy: 0.6066
# Epoch 127/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9831 - accuracy: 0.5988
# Epoch 128/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9847 - accuracy: 0.5978
# Epoch 129/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9791 - accuracy: 0.6072
# Epoch 130/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9776 - accuracy: 0.6054
# Epoch 131/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9774 - accuracy: 0.6023
# Epoch 132/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 0.9670 - accuracy: 0.6071
# Epoch 133/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9680 - accuracy: 0.6101
# Epoch 134/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9750 - accuracy: 0.6030
# Epoch 135/300
# 1131/1131 [==============================] - 11s 10ms/step - loss: 0.9741 - accuracy: 0.6036
# Epoch 136/300
# 1131/1131 [==============================] - 11s 10ms/step - loss: 0.9764 - accuracy: 0.6025
# Epoch 137/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9774 - accuracy: 0.6024
# Epoch 138/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9770 - accuracy: 0.6046
# Epoch 139/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9638 - accuracy: 0.6092
# Epoch 140/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9754 - accuracy: 0.6047
# Epoch 141/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9668 - accuracy: 0.6078
# Epoch 142/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9651 - accuracy: 0.6128
# Epoch 143/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9683 - accuracy: 0.6086
# Epoch 144/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9745 - accuracy: 0.6082
# Epoch 145/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9666 - accuracy: 0.6114
# Epoch 146/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9631 - accuracy: 0.6096
# Epoch 147/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9746 - accuracy: 0.6059
# Epoch 148/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9659 - accuracy: 0.6052
# Epoch 149/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9683 - accuracy: 0.6046
# Epoch 150/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9685 - accuracy: 0.6068
# Epoch 151/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9703 - accuracy: 0.6093
# Epoch 152/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9626 - accuracy: 0.6124
# Epoch 153/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9683 - accuracy: 0.6062
# Epoch 154/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9585 - accuracy: 0.6158
# Epoch 155/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9666 - accuracy: 0.6082
# Epoch 156/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9587 - accuracy: 0.6104
# Epoch 157/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9645 - accuracy: 0.6078
# Epoch 158/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9597 - accuracy: 0.6108
# Epoch 159/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9576 - accuracy: 0.6108
# Epoch 160/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9522 - accuracy: 0.6185
# Epoch 161/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9663 - accuracy: 0.6123
# Epoch 162/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9683 - accuracy: 0.6092
# Epoch 163/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9562 - accuracy: 0.6104
# Epoch 164/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9617 - accuracy: 0.6065
# Epoch 165/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9682 - accuracy: 0.6090
# Epoch 166/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9599 - accuracy: 0.6096
# Epoch 167/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9546 - accuracy: 0.6135
# Epoch 168/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9598 - accuracy: 0.6154
# Epoch 169/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9485 - accuracy: 0.6176
# Epoch 170/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9538 - accuracy: 0.6145
# Epoch 171/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9547 - accuracy: 0.6151
# Epoch 172/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9572 - accuracy: 0.6128
# Epoch 173/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9620 - accuracy: 0.6122
# Epoch 174/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9607 - accuracy: 0.6137
# Epoch 175/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9495 - accuracy: 0.6154
# Epoch 176/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9570 - accuracy: 0.6149
# Epoch 177/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9561 - accuracy: 0.6143
# Epoch 178/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9553 - accuracy: 0.6146
# Epoch 179/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9582 - accuracy: 0.6128
# Epoch 180/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9489 - accuracy: 0.6145
# Epoch 181/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9533 - accuracy: 0.6187
# Epoch 182/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9473 - accuracy: 0.6200
# Epoch 183/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9563 - accuracy: 0.6127
# Epoch 184/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9585 - accuracy: 0.6111
# Epoch 185/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9538 - accuracy: 0.6171
# Epoch 186/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9504 - accuracy: 0.6183
# Epoch 187/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9457 - accuracy: 0.6193
# Epoch 188/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9499 - accuracy: 0.6111
# Epoch 189/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9563 - accuracy: 0.6192
# Epoch 190/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9447 - accuracy: 0.6180
# Epoch 191/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9483 - accuracy: 0.6150
# Epoch 192/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9543 - accuracy: 0.6140
# Epoch 193/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9503 - accuracy: 0.6135
# Epoch 194/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9473 - accuracy: 0.6202
# Epoch 195/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9532 - accuracy: 0.6140
# Epoch 196/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9468 - accuracy: 0.6195
# Epoch 197/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9510 - accuracy: 0.6153
# Epoch 198/300
# 1131/1131 [==============================] - 11s 9ms/step - loss: 0.9428 - accuracy: 0.6168
# Epoch 199/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9485 - accuracy: 0.6196
# Epoch 200/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9407 - accuracy: 0.6190
# Epoch 201/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9524 - accuracy: 0.6118
# Epoch 202/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9486 - accuracy: 0.6144
# Epoch 203/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9470 - accuracy: 0.6155
# Epoch 204/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9449 - accuracy: 0.6170
# Epoch 205/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9432 - accuracy: 0.6213
# Epoch 206/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9446 - accuracy: 0.6198
# Epoch 207/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9532 - accuracy: 0.6154
# Epoch 208/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9412 - accuracy: 0.6182
# Epoch 209/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9527 - accuracy: 0.6187
# Epoch 210/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 0.9467 - accuracy: 0.6186
# Epoch 211/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9429 - accuracy: 0.6190
# Epoch 212/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9451 - accuracy: 0.6229
# Epoch 213/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9393 - accuracy: 0.6181
# Epoch 214/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9424 - accuracy: 0.6175
# Epoch 215/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9416 - accuracy: 0.6174
# Epoch 216/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9401 - accuracy: 0.6261
# Epoch 217/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9464 - accuracy: 0.6154
# Epoch 218/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9496 - accuracy: 0.6164
# Epoch 219/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9443 - accuracy: 0.6221
# Epoch 220/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9453 - accuracy: 0.6198
# Epoch 221/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9411 - accuracy: 0.6205
# Epoch 222/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 0.9344 - accuracy: 0.6260
# Epoch 223/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9424 - accuracy: 0.6191
# Epoch 224/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9417 - accuracy: 0.6166
# Epoch 225/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 0.9360 - accuracy: 0.6174
# Epoch 226/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 0.9365 - accuracy: 0.6209
# Epoch 227/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9398 - accuracy: 0.6191
# Epoch 228/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9412 - accuracy: 0.6179
# Epoch 229/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 0.9431 - accuracy: 0.6197
# Epoch 230/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9411 - accuracy: 0.6221
# Epoch 231/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9361 - accuracy: 0.6224
# Epoch 232/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9346 - accuracy: 0.6229
# Epoch 233/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9467 - accuracy: 0.6165
# Epoch 234/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9396 - accuracy: 0.6207
# Epoch 235/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9372 - accuracy: 0.6212
# Epoch 236/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9454 - accuracy: 0.6196
# Epoch 237/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9388 - accuracy: 0.6195
# Epoch 238/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9485 - accuracy: 0.6219
# Epoch 239/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9459 - accuracy: 0.6198
# Epoch 240/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9443 - accuracy: 0.6250
# Epoch 241/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9303 - accuracy: 0.6263
# Epoch 242/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9357 - accuracy: 0.6246
# Epoch 243/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9376 - accuracy: 0.6212
# Epoch 244/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9319 - accuracy: 0.6224
# Epoch 245/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9400 - accuracy: 0.6176
# Epoch 246/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9361 - accuracy: 0.6271
# Epoch 247/300
# 1131/1131 [==============================] - 10s 8ms/step - loss: 0.9369 - accuracy: 0.6229
# Epoch 248/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9356 - accuracy: 0.6237
# Epoch 249/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9462 - accuracy: 0.6174
# Epoch 250/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9350 - accuracy: 0.6206
# Epoch 251/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9323 - accuracy: 0.6269
# Epoch 252/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9325 - accuracy: 0.6257
# Epoch 253/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9375 - accuracy: 0.6209
# Epoch 254/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9301 - accuracy: 0.6266
# Epoch 255/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9380 - accuracy: 0.6213
# Epoch 256/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9284 - accuracy: 0.6223
# Epoch 257/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9341 - accuracy: 0.6229
# Epoch 258/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9401 - accuracy: 0.6209
# Epoch 259/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9391 - accuracy: 0.6228
# Epoch 260/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9360 - accuracy: 0.6223
# Epoch 261/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9359 - accuracy: 0.6235
# Epoch 262/300
# 1131/1131 [==============================] - 10s 9ms/step - loss: 0.9274 - accuracy: 0.6289
# Epoch 263/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9330 - accuracy: 0.6224
# Epoch 264/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9372 - accuracy: 0.6221
# Epoch 265/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9367 - accuracy: 0.6215
# Epoch 266/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9319 - accuracy: 0.6207
# Epoch 267/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9338 - accuracy: 0.6255
# Epoch 268/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9356 - accuracy: 0.6185
# Epoch 269/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9302 - accuracy: 0.6255
# Epoch 270/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9310 - accuracy: 0.6237
# Epoch 271/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9355 - accuracy: 0.6211
# Epoch 272/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9309 - accuracy: 0.6250
# Epoch 273/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9286 - accuracy: 0.6287
# Epoch 274/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9342 - accuracy: 0.6231
# Epoch 275/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9352 - accuracy: 0.6248
# Epoch 276/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9276 - accuracy: 0.6261
# Epoch 277/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9320 - accuracy: 0.6221
# Epoch 278/300
# 1131/1131 [==============================] - 8s 7ms/step - loss: 0.9236 - accuracy: 0.6290
# Epoch 279/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9309 - accuracy: 0.6266
# Epoch 280/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9314 - accuracy: 0.6279
# Epoch 281/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9419 - accuracy: 0.6215
# Epoch 282/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9347 - accuracy: 0.6278
# Epoch 283/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9342 - accuracy: 0.6249
# Epoch 284/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9340 - accuracy: 0.6239
# Epoch 285/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9329 - accuracy: 0.6253
# Epoch 286/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9377 - accuracy: 0.6248
# Epoch 287/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9303 - accuracy: 0.6259
# Epoch 288/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9306 - accuracy: 0.6226
# Epoch 289/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9342 - accuracy: 0.6219
# Epoch 290/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9278 - accuracy: 0.6254
# Epoch 291/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9290 - accuracy: 0.6284
# Epoch 292/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9287 - accuracy: 0.6289
# Epoch 293/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9335 - accuracy: 0.6235
# Epoch 294/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9162 - accuracy: 0.6294
# Epoch 295/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9381 - accuracy: 0.6219
# Epoch 296/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9302 - accuracy: 0.6254
# Epoch 297/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9326 - accuracy: 0.6232
# Epoch 298/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9279 - accuracy: 0.6276
# Epoch 299/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9285 - accuracy: 0.6278
# Epoch 300/300
# 1131/1131 [==============================] - 9s 8ms/step - loss: 0.9274 - accuracy: 0.6304

# %%
avaliacao = model.evaluate(x_train,y_train)
# Out:
# 566/566 [==============================] - 3s 4ms/step - loss: 0.7335 - accuracy: 0.7436

# %% [markdown]
# Avaliação do Modelo via Matriz de Confusão

# %%
from sklearn.metrics import confusion_matrix

pred = model.predict(x_test)
y_pred = pred.argmax(axis=-1)

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[745 263  68 181 141 119]
#  [197 805  96 155 180  39]
#  [ 74  75 634 300   6 400]
#  [137 139 211 755  39 208]
#  [214 377  50  81 719  38]
#  [107  78 285 350   3 641]]

# %%
qualidade = cm.diagonal()/cm.sum(axis=1)
qualidade
# Out:
# array([0.49110086, 0.546875  , 0.42578912, 0.50705171, 0.48613928,
#        0.43784153])

# %%
import matplotlib.pyplot as plt

grupos = ['cly', 'hook', 'lat', 'palm', 'spher', 'tip']
plt.bar(grupos, qualidade)
plt.xlabel('Movimentos')
plt.ylabel('%')
plt.title('Porcentagem de Acertos na Classificação dos Movimentos')
plt.show()

# %%
desvio = np.std(qualidade)
desvio
# Out:
# 0.040915853340619875

# %%
df_cm = pd.DataFrame(cm, range(6),range(6))

# %%
pip install pretty_confusion_matrix
# Out:
# Collecting pretty_confusion_matrix
#   Downloading pretty_confusion_matrix-0.1.1-py3-none-any.whl (9.6 kB)
# Collecting flake8<4.0.0,>=3.9.2
#   Downloading flake8-3.9.2-py2.py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 1.1 MB/s
# Collecting isort<6.0.0,>=5.8.0
#   Downloading isort-5.10.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 33.2 MB/s
# Collecting pre-commit<3.0.0,>=2.12.1
#   Downloading pre_commit-2.16.0-py2.py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 60.0 MB/s
# Collecting black<22.0,>=21.5b0
#   Downloading black-21.12b0-py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 42.1 MB/s
# Collecting numpy<2.0.0,>=1.21.4
#   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 51.9 MB/s
# Collecting matplotlib<4.0.0,>=3.5.0
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 36.6 MB/s
# Collecting pandas<2.0.0,>=1.3.4
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 55.0 MB/s
# Requirement already satisfied: seaborn<0.12.0,>=0.11.2 in /usr/local/lib/python3.7/dist-packages (from pretty_confusion_matrix) (0.11.2)
# Requirement already satisfied: sklearn<0.1,>=0.0 in /usr/local/lib/python3.7/dist-packages (from pretty_confusion_matrix) (0.0)
# Collecting tomli<2.0.0,>=0.2.6
#   Downloading tomli-1.2.3-py3-none-any.whl (12 kB)
# Collecting platformdirs>=2
#   Downloading platformdirs-2.4.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.7/dist-packages (from black<22.0,>=21.5b0->pretty_confusion_matrix) (3.10.0.2)
# Requirement already satisfied: click>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from black<22.0,>=21.5b0->pretty_confusion_matrix) (7.1.2)
# Collecting typed-ast>=1.4.2
#   Downloading typed_ast-1.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 67.1 MB/s
# Collecting pathspec<1,>=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting pycodestyle<2.8.0,>=2.7.0
#   Downloading pycodestyle-2.7.0-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 532 kB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from flake8<4.0.0,>=3.9.2->pretty_confusion_matrix) (4.10.0)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pyflakes<2.4.0,>=2.3.0
#   Downloading pyflakes-2.3.1-py2.py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 5.8 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.0->pretty_confusion_matrix) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.0->pretty_confusion_matrix) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.0->pretty_confusion_matrix) (3.0.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.0->pretty_confusion_matrix) (7.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.0->pretty_confusion_matrix) (21.3)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.28.5-py3-none-any.whl (890 kB)
#      |████████████████████████████████| 890 kB 43.4 MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.5.0->pretty_confusion_matrix) (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.4->pretty_confusion_matrix) (2018.9)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 56.4 MB/s
# Collecting nodeenv>=0.11.1
#   Downloading nodeenv-1.6.0-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pre-commit<3.0.0,>=2.12.1->pretty_confusion_matrix) (0.10.2)
# Collecting cfgv>=2.0.0
#   Downloading cfgv-3.3.1-py2.py3-none-any.whl (7.3 kB)
# Collecting virtualenv>=20.0.8
#   Downloading virtualenv-20.13.0-py2.py3-none-any.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 53.1 MB/s
# Collecting identify>=1.0.0
#   Downloading identify-2.4.4-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 6.2 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.5.0->pretty_confusion_matrix) (1.15.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from seaborn<0.12.0,>=0.11.2->pretty_confusion_matrix) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn<0.1,>=0.0->pretty_confusion_matrix) (1.0.2)
# Requirement already satisfied: filelock<4,>=3.2 in /usr/local/lib/python3.7/dist-packages (from virtualenv>=20.0.8->pre-commit<3.0.0,>=2.12.1->pretty_confusion_matrix) (3.4.2)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.4-py2.py3-none-any.whl (461 kB)
#      |████████████████████████████████| 461 kB 50.5 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->flake8<4.0.0,>=3.9.2->pretty_confusion_matrix) (3.7.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn<0.1,>=0.0->pretty_confusion_matrix) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn<0.1,>=0.0->pretty_confusion_matrix) (1.1.0)
# Installing collected packages: numpy, platformdirs, fonttools, distlib, virtualenv, typed-ast, tomli, pyyaml, pyflakes, pycodestyle, pathspec, pandas, nodeenv, mypy-extensions, mccabe, matplotlib, identify, cfgv, pre-commit, isort, flake8, black, pretty-confusion-matrix
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: tomli
#     Found existing installation: tomli 2.0.0
#     Uninstalling tomli-2.0.0:
#       Successfully uninstalled tomli-2.0.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.5 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.5 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed black-21.12b0 cfgv-3.3.1 distlib-0.3.4 flake8-3.9.2 fonttools-4.28.5 identify-2.4.4 isort-5.10.1 matplotlib-3.5.1 mccabe-0.6.1 mypy-extensions-0.4.3 nodeenv-1.6.0 numpy-1.21.5 pandas-1.3.5 pathspec-0.9.0 platformdirs-2.4.1 pre-commit-2.16.0 pretty-confusion-matrix-0.1.1 pycodestyle-2.7.0 pyflakes-2.3.1 pyyaml-6.0 tomli-1.2.3 typed-ast-1.5.1 virtualenv-20.13.0

# %%
import numpy as np
from pretty_confusion_matrix import pp_matrix

pp_matrix(df_cm)
# Out:
# /usr/local/lib/python3.7/dist-packages/pretty_confusion_matrix/pretty_confusion_matrix.py:200: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
#   t.tick1On = False
# /usr/local/lib/python3.7/dist-packages/pretty_confusion_matrix/pretty_confusion_matrix.py:201: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.
#   t.tick2On = False
# /usr/local/lib/python3.7/dist-packages/pretty_confusion_matrix/pretty_confusion_matrix.py:203: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
#   t.tick1On = False
# /usr/local/lib/python3.7/dist-packages/pretty_confusion_matrix/pretty_confusion_matrix.py:204: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.
#   t.tick2On = False
